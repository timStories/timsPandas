# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#load the data
df = pd.read_csv('./games.csv')
df
# Out:
# C:\Users\tschm\AppData\Local\Temp\ipykernel_19264\1654953054.py:2: DtypeWarning: Columns (5,15,19,20,21,22,23,26,27,28,36,37,43,44,45,46,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./games.csv')
#          AppID                    Name  Release date Estimated owners  \
# 0        20200        Galactic Bowling  Oct 21, 2008        0 - 20000
# 1       655370            Train Bandit  Oct 12, 2017        0 - 20000
# 2      1732930            Jolt Project  Nov 17, 2021        0 - 20000
# 3      1355720                Henosis™  Jul 23, 2020        0 - 20000
# 4      1139950   Two Weeks in Painland   Feb 3, 2020        0 - 20000
# ...        ...                     ...           ...              ...
# 97097  3080940  Femdom Game World: Mom  Aug 22, 2024        0 - 20000
# 97098  2593970             Blocky Farm  Aug 30, 2024            0 - 0
# 97099  3137150    Infiltrate & Extract  Aug 30, 2024            0 - 0
# 97100  3124670       Escape The Garage  Aug 29, 2024            0 - 0
# 97101  3054200              Lober Lobe  Aug 30, 2024            0 - 0
#
#       Peak CCU Required age  Price Discount  DLC count  \
# 0            0            0  19,99        0          0
# 1            0            0   0,99        0          0
# 2            0            0   4,99        0          0
# 3            0            0   5,99        0          0
# 4            0            0      0        0          0
# ...        ...          ...    ...      ...        ...
# 97097        0            0   4,19        0          0
# 97098        0            0   8,99        0          0
# 97099        0            0      0        0          0
# 97100        0            0   4,99        0          0
# 97101        0            0   4,49        0          0
#
#                                      Supported languages  ... Unnamed: 40  \
# 0                                            ['English']  ...         NaN
# 1      ['English', 'French', 'Italian', 'German', 'Sp...  ...         NaN
# 2                     ['English', 'Portuguese - Brazil']  ...         NaN
# 3      ['English', 'French', 'Italian', 'German', 'Sp...  ...         NaN
# 4                         ['English', 'Spanish - Spain']  ...         NaN
# ...                                                  ...  ...         ...
# 97097                             ['English', 'Russian']  ...         NaN
# 97098  ['English', 'French', 'Italian', 'German', 'Sp...  ...         NaN
# 97099                                        ['English']  ...         NaN
# 97100                                        ['English']  ...         NaN
# 97101                                        ['English']  ...         NaN
#
#       Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 97097         NaN         NaN         NaN         NaN         NaN         NaN
# 97098         NaN         NaN         NaN         NaN         NaN         NaN
# 97099         NaN         NaN         NaN         NaN         NaN         NaN
# 97100         NaN         NaN         NaN         NaN         NaN         NaN
# 97101         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 47 Unnamed: 48 Unnamed: 49
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# 2             NaN         NaN         NaN
# 3             NaN         NaN         NaN
# 4             NaN         NaN         NaN
# ...           ...         ...         ...
# 97097         NaN         NaN         NaN
# 97098         NaN         NaN         NaN
# 97099         NaN         NaN         NaN
# 97100         NaN         NaN         NaN
# 97101         NaN         NaN         NaN
#
# [97102 rows x 50 columns]

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_6b9d0 thead>tr>th {
#   text-align: left;
# }
# #T_6b9d0_row0_col0, #T_6b9d0_row1_col0, #T_6b9d0_row2_col0, #T_6b9d0_row3_col0, #T_6b9d0_row4_col0, #T_6b9d0_row5_col0, #T_6b9d0_row6_col0, #T_6b9d0_row7_col0, #T_6b9d0_row8_col0, #T_6b9d0_row9_col0, #T_6b9d0_row10_col0, #T_6b9d0_row11_col0, #T_6b9d0_row12_col0, #T_6b9d0_row13_col0, #T_6b9d0_row14_col0, #T_6b9d0_row15_col0, #T_6b9d0_row16_col0, #T_6b9d0_row17_col0, #T_6b9d0_row18_col0, #T_6b9d0_row19_col0, #T_6b9d0_row20_col0, #T_6b9d0_row21_col0, #T_6b9d0_row22_col0, #T_6b9d0_row23_col0, #T_6b9d0_row24_col0, #T_6b9d0_row25_col0, #T_6b9d0_row26_col0, #T_6b9d0_row27_col0, #T_6b9d0_row28_col0, #T_6b9d0_row29_col0, #T_6b9d0_row30_col0, #T_6b9d0_row31_col0, #T_6b9d0_row32_col0, #T_6b9d0_row33_col0, #T_6b9d0_row34_col0, #T_6b9d0_row35_col0, #T_6b9d0_row36_col0, #T_6b9d0_row37_col0, #T_6b9d0_row38_col0, #T_6b9d0_row39_col0, #T_6b9d0_row40_col0, #T_6b9d0_row41_col0, #T_6b9d0_row42_col0, #T_6b9d0_row43_col0, #T_6b9d0_row44_col0, #T_6b9d0_row45_col0, #T_6b9d0_row46_col0, #T_6b9d0_row47_col0, #T_6b9d0_row48_col0, #T_6b9d0_row49_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_6b9d0_row0_col1, #T_6b9d0_row1_col1, #T_6b9d0_row2_col1, #T_6b9d0_row3_col1, #T_6b9d0_row4_col1, #T_6b9d0_row5_col1, #T_6b9d0_row6_col1, #T_6b9d0_row7_col1, #T_6b9d0_row8_col1, #T_6b9d0_row9_col1, #T_6b9d0_row10_col1, #T_6b9d0_row11_col1, #T_6b9d0_row12_col1, #T_6b9d0_row13_col1, #T_6b9d0_row14_col1, #T_6b9d0_row15_col1, #T_6b9d0_row16_col1, #T_6b9d0_row17_col1, #T_6b9d0_row18_col1, #T_6b9d0_row19_col1, #T_6b9d0_row20_col1, #T_6b9d0_row21_col1, #T_6b9d0_row22_col1, #T_6b9d0_row23_col1, #T_6b9d0_row24_col1, #T_6b9d0_row25_col1, #T_6b9d0_row26_col1, #T_6b9d0_row27_col1, #T_6b9d0_row28_col1, #T_6b9d0_row29_col1, #T_6b9d0_row30_col1, #T_6b9d0_row31_col1, #T_6b9d0_row32_col1, #T_6b9d0_row33_col1, #T_6b9d0_row34_col1, #T_6b9d0_row35_col1, #T_6b9d0_row36_col1, #T_6b9d0_row37_col1, #T_6b9d0_row38_col1, #T_6b9d0_row39_col1, #T_6b9d0_row40_col1, #T_6b9d0_row41_col1, #T_6b9d0_row42_col1, #T_6b9d0_row43_col1, #T_6b9d0_row44_col1, #T_6b9d0_row45_col1, #T_6b9d0_row46_col1, #T_6b9d0_row47_col1, #T_6b9d0_row48_col1, #T_6b9d0_row49_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_6b9d0_row0_col2, #T_6b9d0_row1_col2, #T_6b9d0_row2_col2, #T_6b9d0_row3_col2, #T_6b9d0_row4_col2, #T_6b9d0_row5_col2, #T_6b9d0_row6_col2, #T_6b9d0_row7_col2, #T_6b9d0_row8_col2, #T_6b9d0_row9_col2, #T_6b9d0_row10_col2, #T_6b9d0_row11_col2, #T_6b9d0_row12_col2, #T_6b9d0_row13_col2, #T_6b9d0_row14_col2, #T_6b9d0_row15_col2, #T_6b9d0_row16_col2, #T_6b9d0_row17_col2, #T_6b9d0_row18_col2, #T_6b9d0_row19_col2, #T_6b9d0_row20_col2, #T_6b9d0_row21_col2, #T_6b9d0_row22_col2, #T_6b9d0_row23_col2, #T_6b9d0_row24_col2, #T_6b9d0_row25_col2, #T_6b9d0_row26_col2, #T_6b9d0_row27_col2, #T_6b9d0_row28_col2, #T_6b9d0_row29_col2, #T_6b9d0_row30_col2, #T_6b9d0_row31_col2, #T_6b9d0_row32_col2, #T_6b9d0_row33_col2, #T_6b9d0_row34_col2, #T_6b9d0_row35_col2, #T_6b9d0_row36_col2, #T_6b9d0_row37_col2, #T_6b9d0_row38_col2, #T_6b9d0_row39_col2, #T_6b9d0_row40_col2, #T_6b9d0_row41_col2, #T_6b9d0_row42_col2, #T_6b9d0_row43_col2, #T_6b9d0_row44_col2, #T_6b9d0_row45_col2, #T_6b9d0_row46_col2, #T_6b9d0_row47_col2, #T_6b9d0_row48_col2, #T_6b9d0_row49_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_6b9d0_row0_col3, #T_6b9d0_row1_col3, #T_6b9d0_row2_col3, #T_6b9d0_row3_col3, #T_6b9d0_row4_col3, #T_6b9d0_row5_col3, #T_6b9d0_row6_col3, #T_6b9d0_row7_col3, #T_6b9d0_row8_col3, #T_6b9d0_row9_col3, #T_6b9d0_row10_col3, #T_6b9d0_row11_col3, #T_6b9d0_row12_col3, #T_6b9d0_row13_col3, #T_6b9d0_row14_col3, #T_6b9d0_row15_col3, #T_6b9d0_row16_col3, #T_6b9d0_row17_col3, #T_6b9d0_row18_col3, #T_6b9d0_row19_col3, #T_6b9d0_row20_col3, #T_6b9d0_row21_col3, #T_6b9d0_row22_col3, #T_6b9d0_row23_col3, #T_6b9d0_row24_col3, #T_6b9d0_row25_col3, #T_6b9d0_row26_col3, #T_6b9d0_row27_col3, #T_6b9d0_row28_col3, #T_6b9d0_row29_col3, #T_6b9d0_row30_col3, #T_6b9d0_row31_col3, #T_6b9d0_row32_col3, #T_6b9d0_row33_col3, #T_6b9d0_row34_col3, #T_6b9d0_row35_col3, #T_6b9d0_row36_col3, #T_6b9d0_row37_col3, #T_6b9d0_row38_col3, #T_6b9d0_row39_col3, #T_6b9d0_row40_col3, #T_6b9d0_row41_col3, #T_6b9d0_row42_col3, #T_6b9d0_row43_col3, #T_6b9d0_row44_col3, #T_6b9d0_row45_col3, #T_6b9d0_row46_col3, #T_6b9d0_row47_col3, #T_6b9d0_row48_col3, #T_6b9d0_row49_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_6b9d0_row0_col4, #T_6b9d0_row1_col4, #T_6b9d0_row2_col4, #T_6b9d0_row3_col4, #T_6b9d0_row4_col4, #T_6b9d0_row5_col4, #T_6b9d0_row6_col4, #T_6b9d0_row7_col4, #T_6b9d0_row8_col4, #T_6b9d0_row9_col4, #T_6b9d0_row10_col4, #T_6b9d0_row11_col4, #T_6b9d0_row12_col4, #T_6b9d0_row13_col4, #T_6b9d0_row14_col4, #T_6b9d0_row15_col4, #T_6b9d0_row16_col4, #T_6b9d0_row17_col4, #T_6b9d0_row18_col4, #T_6b9d0_row19_col4, #T_6b9d0_row20_col4, #T_6b9d0_row21_col4, #T_6b9d0_row22_col4, #T_6b9d0_row23_col4, #T_6b9d0_row24_col4, #T_6b9d0_row25_col4, #T_6b9d0_row26_col4, #T_6b9d0_row27_col4, #T_6b9d0_row28_col4, #T_6b9d0_row29_col4, #T_6b9d0_row30_col4, #T_6b9d0_row31_col4, #T_6b9d0_row32_col4, #T_6b9d0_row33_col4, #T_6b9d0_row34_col4, #T_6b9d0_row35_col4, #T_6b9d0_row36_col4, #T_6b9d0_row37_col4, #T_6b9d0_row38_col4, #T_6b9d0_row39_col4, #T_6b9d0_row40_col4, #T_6b9d0_row41_col4, #T_6b9d0_row42_col4, #T_6b9d0_row43_col4, #T_6b9d0_row44_col4, #T_6b9d0_row45_col4, #T_6b9d0_row46_col4, #T_6b9d0_row47_col4, #T_6b9d0_row48_col4, #T_6b9d0_row49_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_6b9d0_row0_col5, #T_6b9d0_row1_col5, #T_6b9d0_row2_col5, #T_6b9d0_row3_col5, #T_6b9d0_row4_col5, #T_6b9d0_row5_col5, #T_6b9d0_row6_col5, #T_6b9d0_row7_col5, #T_6b9d0_row8_col5, #T_6b9d0_row9_col5, #T_6b9d0_row10_col5, #T_6b9d0_row11_col5, #T_6b9d0_row12_col5, #T_6b9d0_row13_col5, #T_6b9d0_row14_col5, #T_6b9d0_row15_col5, #T_6b9d0_row16_col5, #T_6b9d0_row17_col5, #T_6b9d0_row18_col5, #T_6b9d0_row19_col5, #T_6b9d0_row20_col5, #T_6b9d0_row21_col5, #T_6b9d0_row22_col5, #T_6b9d0_row23_col5, #T_6b9d0_row24_col5, #T_6b9d0_row25_col5, #T_6b9d0_row26_col5, #T_6b9d0_row27_col5, #T_6b9d0_row28_col5, #T_6b9d0_row29_col5, #T_6b9d0_row30_col5, #T_6b9d0_row31_col5, #T_6b9d0_row32_col5, #T_6b9d0_row33_col5, #T_6b9d0_row34_col5, #T_6b9d0_row35_col5, #T_6b9d0_row36_col5, #T_6b9d0_row37_col5, #T_6b9d0_row38_col5, #T_6b9d0_row39_col5, #T_6b9d0_row40_col5, #T_6b9d0_row41_col5, #T_6b9d0_row42_col5, #T_6b9d0_row43_col5, #T_6b9d0_row44_col5, #T_6b9d0_row45_col5, #T_6b9d0_row46_col5, #T_6b9d0_row47_col5, #T_6b9d0_row48_col5, #T_6b9d0_row49_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_6b9d0">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 97,102 x 50<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_6b9d0_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_6b9d0_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_6b9d0_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_6b9d0_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_6b9d0_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_6b9d0_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6b9d0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6b9d0_row0_col1" class="data row0 col1" ><strong>AppID</strong><br>[int64]</td>
#       <td id="T_6b9d0_row0_col2" class="data row0 col2" >Mean (sd) : 1525417.8 (800017.1)<br>min < med < max:<br>10.0 < 1491020.0 < 3199580.0<br>IQR (CV) : 1332995.0 (1.9)</td>
